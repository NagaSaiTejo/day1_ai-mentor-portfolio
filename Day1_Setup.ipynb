# %% [markdown]
# <a href="https://colab.research.google.com/github/NagaSaiTejo/day1_ai-mentor-portfolio/blob/main/Day1_Setup.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q google-genai

# %%
import os, getpass
os.environ['GEMINI_API_KEY'] = getpass.getpass('Paste your Google AI Studio key: ')
# Out:
# Paste your Google AI Studio key: ··········

# %%
from google import genai
client = genai.Client(api_key=os.environ['GEMINI_API_KEY'])

resp = client.models.generate_content(
    model='gemini-2.5-flash',
    contents='Explain the 5-Layer AI Skill Pyramid in 4 short bullet points.'
)
print(resp.text)
# Out:
# The 5-Layer AI Skill Pyramid outlines the diverse, hierarchical skills needed for successful AI development and deployment, from fundamental technical work to strategic leadership.
#
# Here are 4 short bullet points explaining it:
#
# *   **Foundation (Data & ML Engineering):** The base involves core **Data Science & ML Engineering** skills for data processing, model building, and foundational algorithm development.
# *   **Operationalization (MLOps):** The next layer focuses on **MLOps & Platform Engineering** to deploy, manage, and scale AI models reliably in production environments.
# *   **Strategy & Ethics (Product & Governance):** Higher up are **AI Product Management & Strategy** (aligning AI with business value) and **AI Ethics & Governance** (ensuring responsible and fair AI systems).
# *   **Apex (Research & Innovation):** At the top is **AI Research & Frontier Development**, pushing the boundaries of AI capabilities and exploring new breakthroughs.
