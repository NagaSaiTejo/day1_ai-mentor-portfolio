# %% [markdown]
# <a href="https://colab.research.google.com/github/NagaSaiTejo/day1_ai-mentor-portfolio/blob/main/Day1_Setup1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q groq
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.7/143.7 kB 3.5 MB/s eta 0:00:00

# %%
import os, getpass

os.environ["GROQ_API_KEY"] = getpass.getpass("Paste your Groq API Key: ")
# Out:
# Paste your Groq API Key: ··········

# %%
from groq import Groq

client = Groq(
    api_key=os.environ["GROQ_API_KEY"]
)

response = client.chat.completions.create(
    model="llama-3.3-70b-versatile",
    messages=[
        {
            "role": "user",
            "content": "Explain the 5-Layer AI Skill Pyramid in 4 short bullet points."
        }
    ]
)

print(response.choices[0].message.content)
# Out:
# The 5-Layer AI Skill Pyramid is a framework that outlines the progression of skills required for a career in Artificial Intelligence (AI). Here are 4 key points about the pyramid in brief:
#
# * The base of the pyramid consists of foundational skills in mathematics and computer science.
# * The next layers build upon this foundation, adding skills in programming languages, data structures, and software engineering.
# * The higher layers of the pyramid focus on specialized AI skills, including machine learning, deep learning, and natural language processing.
# * The apex of the pyramid represents expertise in strategy, research, and innovation, where professionals can apply their skills to drive business value and advance the field of AI.
